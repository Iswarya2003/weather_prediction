# %% [markdown]
# <a href="https://colab.research.google.com/github/Iswarya2003/weather_prediction/blob/main/weatherprediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np  # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-43bd7792-4abd-46b1-b07c-b532280a5df8" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-43bd7792-4abd-46b1-b07c-b532280a5df8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving weather.csv to weather.csv
# {'weather.csv': b'date,temperaturemin,temperaturemax,precipitation,snowfall,snowdepth,avgwindspeed,fastest2minwinddir,fastest2minwindspeed,fastest5secwinddir,fastest5secwindspeed,fog,fogheavy,mist,rain,fogground,ice,glaze,drizzle,snow,freezingrain,smokehaze,thunder,highwind,hail,blowingsnow,dust,freezingfog\n2011-02-13,25,61,0,0,0,6.93,230,17.9,220,23.94,No,No,No,No,No,No,No,No,No,No,No,No,No,No,No,No,No\n2011-02-16,34,63,0,0,0,5.37,230,17.9,230,21.92,No,No,No,No,No,No,No,No,No,No,No,No,No,No,No,No,No\n2011-02-18,52,78.1,0,0,0,10.74,230,17.9,280,23.04,Yes,No,Yes,No,No,No,No,No,No,No,Yes,No,No,No,No,No,No\n2011-03-03,35.1,53.1,0,0,0,10.74,70,21.03,80,29.08,No,No,No,No,No,No,No,No,No,No,No,No,No,No,No,No,No\n2011-03-16,46.9,64,0.05,0,0,2.91,270,10.07,300,14.09,Yes,No,Yes,Yes,No,No,No,No,No,No,No,No,No,No,No,No,No\n2011-03-19,55.9,75,0,0,0,5.82,40,17.9,50,25.05,No,No,No,No,No,No,No,No,No,No,No,No,No,No,No,No,No\n2011-03-21,52,75,0,0,0,12.75,240,27.96,240,36.01,No,No,No,No,No,No,No,No,No,No,No,No,No,No,No,No,No\n2011-03-23,50,82.9,0.45,0,0,6.71,230,25.95,220,36.01,Yes,No,Yes,Yes,No,No,No,No,No,No,No,Yes,No,No,No,No,No\n2011-03-30,39.9,48,1.05,0,0,7.83,100,21.92,100,29.08,Yes,Yes,Yes,Yes,No,No,No,Yes,No,No,No,No,No,No,No,No,No\n2011-04-01,37.9,55,0,0,0,6.26,280,17.9,290,29.97,Yes,No,No,No,No,No,No,No,No,No,No,No,No,No,No,No,No\n2011-04-02,37,64.9,0,0,0,8.95,270,27.96,280,42.95,No,No,No,Yes,No,No,No,No,No,No,No,No,No,No,No,No,No\n2011-04-07,46,79,0,0,0,6.49,230,14.99,220,17.9,No,No,No,No,No,No,No,No,No,No,No,No,No,No,No,No,No\n2011-04-08,53.1,82,0.06,0,0,5.14,30,21.92,20,31.99,Yes,No,Yes,Yes,No,No,No,No,No,No,No,Yes,No,No,No,No,No\n2011-04-10,52,72,0,0,0,3.8,210,8.95,200,14.09,Yes,Yes,Yes,No,No,No,No,Yes,No,No,No,No,No,No,No,No,No\n2011-04-26,68,82.9,0,0,0,10.29,190,17.9,190,25.05,No,No,No,Yes,No,No,No,No,No,No,No,Yes,No,No,No,No,No\n2011-04-27,68,87.1,0.21,0,0,12.97,230,29.97,230,40.94,Yes,No,No,Yes,No,No,No,Yes,No,No,No,Yes,No,No,No,No,No\n2011-05-14,63,79,0.12,0,0,4.7,170,14.09,170,16.11,Yes,No,Yes,Yes,No,No,No,No,No,No,No,Yes,No,No,No,No,No\n2011-05-17,57.9,72,0.17,0,0,7.16,180,16.11,160,21.92,Yes,No,Yes,Yes,No,No,No,No,No,No,No,Yes,No,No,No,No,No\n2011-05-20,57,82,0,0,0,2.68,260,12.08,240,17,No,No,No,Yes,No,No,No,No,No,No,No,No,No,No,No,No,No\n2011-05-22,59,89.1,0,0,0,4.03,280,12.08,290,17.9,No,No,No,No,No,No,No,No,No,No,No,No,No,No,No,No,No\n2011-05-23,66,91,0.09,0,0,7.38,230,19.91,210,25.05,Yes,No,Yes,Yes,No,No,No,No,No,No,No,Yes,No,No,No,No,No\n2011-06-02,70,95,0,0,0,2.91,20,10.07,30,16.11,Yes,No,Yes,No,No,No,No,No,No,No,Yes,No,No,No,No,No,No\n2011-06-03,66,84.9,0,0,0,6.93,40,16.11,40,21.92,No,No,No,No,No,No,No,No,No,No,No,No,No,No,No,No,No\n2011-06-05,69.1,90,0,0,0,5.82,40,16.11,50,17.9,No,No,No,No,No,No,No,No,No,No,No,No,No,No,No,No,No\n2011-06-06,69.1,90,0,0,0,4.7,50,12.97,20,19.91,No,No,No,No,No,No,No,No,No,No,No,No,No,No,No,No,No\n2011-06-10,72,96.1,0,0,0,7.38,140,12.97,80,31.99,No,No,No,Yes,No,No,No,No,No,No,No,Yes,No,No,No,No,No\n2011-06-12,66.9,93.9,0.24,0,0,5.59,300,23.04,310,34.9,Yes,No,Yes,Yes,No,No,No,No,No,No,No,Yes,No,No,No,No,No\n2011-06-16,68,91,0,0,0,8.5,230,19.91,200,23.94,No,No,No,No,No,No,No,No,No,No,No,No,No,No,No,No,No\n2011-06-17,66.9,91.9,0,0,0,4.92,230,14.99,150,31.09,No,No,No,No,No,No,No,No,No,No,No,No,No,No,No,No,No\n2011-06-24,72,96.1,0.02,0,0,11.41,230,21.92,240,31.99,No,No,No,Yes,No,No,No,No,No,No,No,No,No,No,No,No,No\n2011-09-21,66.9,82.9,0.43,0,0,3.36,120,8.05,,,Yes,No,No,Yes,No,No,No,Yes,No,No,No,Yes,No,No,No,No,No\n2011-09-24,66.9,78.1,0.03,0,0,3.8,90,8.05,,,Yes,Yes,Yes,Yes,No,No,No,No,No,No,No,No,No,No,No,No,No\n2011-09-26,68,84.9,0,0,0,2.91,160,17.9,160,25.95,No,No,No,No,No,No,No,No,No,No,No,No,No,No,No,No,No\n2011-09-29,61,84,0,0,0,4.25,240,16.11,280,21.92,Yes,No,Yes,No,No,No,No,No,No,No,No,No,No,No,No,No,No\n2011-10-10,55.9,75,0,0,0,6.71,50,12.08,50,14.99,No,No,No,No,No,No,No,No,No,No,No,No,No,No,No,No,No\n2011-10-18,59,82.9,1.04,0,0,6.26,170,14.09,160,19.91,No,No,Yes,Yes,No,No,No,Yes,No ...

# %%
dataset = pd.read_csv("./weather.csv")
temp=dataset['temperaturemin']
precipitation=dataset['precipitation']

# %%
dataset.head(10)
# Out:
#          date  temperaturemin  temperaturemax  precipitation  snowfall  \
# 0  2011-02-13            25.0            61.0           0.00       0.0
# 1  2011-02-16            34.0            63.0           0.00       0.0
# 2  2011-02-18            52.0            78.1           0.00       0.0
# 3  2011-03-03            35.1            53.1           0.00       0.0
# 4  2011-03-16            46.9            64.0           0.05       0.0
# 5  2011-03-19            55.9            75.0           0.00       0.0
# 6  2011-03-21            52.0            75.0           0.00       0.0
# 7  2011-03-23            50.0            82.9           0.45       0.0
# 8  2011-03-30            39.9            48.0           1.05       0.0
# 9  2011-04-01            37.9            55.0           0.00       0.0
#
#    snowdepth  avgwindspeed  fastest2minwinddir  fastest2minwindspeed  \
# 0        0.0          6.93               230.0                 17.90
# 1        0.0          5.37               230.0                 17.90
# 2        0.0         10.74               230.0                 17.90
# 3        0.0         10.74                70.0                 21.03
# 4        0.0          2.91               270.0                 10.07
# 5        0.0          5.82                40.0                 17.90
# 6        0.0         12.75               240.0                 27.96
# 7        0.0          6.71               230.0                 25.95
# 8        0.0          7.83               100.0                 21.92
# 9        0.0          6.26               280.0                 17.90
#
#    fastest5secwinddir  ...  drizzle snow freezingrain smokehaze thunder  \
# 0               220.0  ...       No   No           No        No      No
# 1               230.0  ...       No   No           No        No      No
# 2               280.0  ...       No   No           No       Yes      No
# 3                80.0  ...       No   No           No        No      No
# 4               300.0  ...       No   No           No        No      No
# 5                50.0  ...       No   No           No        No      No
# 6               240.0  ...       No   No           No        No      No
# 7               220.0  ...       No   No           No        No     Yes
# 8               100.0  ...      Yes   No           No        No      No
# 9               290.0  ...       No   No           No        No      No
#
#   highwind hail blowingsnow dust freezingfog
# 0       No   No          No   No          No
# 1       No   No          No   No          No
# 2       No   No          No   No          No
# 3       No   No          No   No          No
# 4       No   No          No   No          No
# 5       No   No          No   No          No
# 6       No   No          No   No          No
# 7       No   No          No   No          No
# 8       No   No          No   No          No
# 9       No   No          No   No          No
#
# [10 rows x 28 columns]

# %%
x = np.array(temp).reshape(-1, 1) # function name says it : reshape the array
y = np.array(precipitation)

# %%
from sklearn.model_selection import train_test_split 
xtrain, xtest, ytrain, ytest = train_test_split( x, y, test_size=1/3, random_state=0 )
from sklearn.linear_model import LinearRegression 
regressor = LinearRegression()
regressor.fit( xtrain, ytrain )
regressor.coef_ , regressor.intercept_
# Out:
# (array([0.00272922]), -0.00979683568563744)

# %%
actualValue = ytrain
predictedValue = regressor.predict(xtrain) 
xtrain[0], actualValue[0] , predictedValue[0]
# Out:
# (array([35.1]), 0.0, 0.08599882176044459)

# %%
regressor.coef_ * xtrain[0] + regressor.intercept_
np.sqrt ( sum( abs( actualValue**2 - predictedValue**2 ) ) ) / len( xtrain )
# Out:
# 0.00720424776737392

# %%
plt.scatter(xtrain, ytrain, color='green') # x = xtrain , y = ytrain

#Predicted values
prediction = regressor.predict(xtrain)
plt.plot(xtrain, prediction , color = 'black') # y = prediction

plt.title ("Prediction for Training Dataset")
plt.xlabel("Temperature in degree"), plt.ylabel("Precipitation")
plt.show()

# %%
plt.scatter(xtest, ytest, color= 'green')

plt.plot(xtrain, regressor.predict(xtrain), color = 'black')

plt.title ("Training Dataset")
plt.xlabel("Tempertaure in degree"), plt.ylabel("Precipitation")
plt.show()

# %%
d=dataset['avgwindspeed'].value_counts()
d.plot(kind='bar')
